# %%
x = var('x')
f(x) = abs(x^2-4)
fig  = plot(f, (x, -4, 4) ,ymin = -2, ymax = 6, gridlines=True, axes_labels=['$x$', '$y$'], figsize = (6, 6), thickness = 2)
fig.fontsize(21)
fig
# Out:
# Graphics object consisting of 1 graphics primitive
