# %% [markdown]
# ### There is no correlation

# %%
import numpy as np

x = np.random.randint(0, 50, 15)
y = np.random.randint(0, 50, 15)

example_points = []

for i in range(15):
    example_points.append((x[i], y[i]))
    

fig = points(example_points, color='blue', pointsize=50, figsize=(6, 6), gridlines=True, axes_labels=['$x$', '$y$'])

fig.fontsize(25)

fig
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ### There is an inverse linear correlation¶

# %%
X = np.linspace(0, 50)
Y = (-2 * X) + 140 + 15 * np.random.randn(50)
data = np.hstack((X.reshape(50, 1),Y.reshape(50, 1)))
fig = points(data, color='blue', pointsize=50, figsize=(6, 6), gridlines=True, axes_labels=['$x$', '$y$'])
fig.fontsize(25)
fig
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ### There is a direct linear correlation

# %%
X = np.linspace(0, 50)
Y = (2 * X)  + 15 * np.random.randn(50)
data = np.hstack((X.reshape(50, 1),Y.reshape(50, 1)))
fig = points(data, color='blue', pointsize=50, figsize=(6, 6), gridlines=True, axes_labels=['$x$', '$y$'])
fig.fontsize(25)
fig
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ### Moderate direct correlation

# %%
x = var('x')
X = np.linspace(0, 50)
Y = (X)  +  7 * np.random.randn(50)
data = np.hstack((X.reshape(50, 1),Y.reshape(50, 1)))
fig = points(data, color='blue', pointsize=50, figsize=(6, 6), gridlines=True, axes_labels=['$x$', '$y$'])
fig += plot(x, (x, 0, 50), ymin=0, ymax=50, gridlines=True, axes_labels=['$x$', '$y$'], figsize=(6, 6), thickness=2.6, rgbcolor=(90/256, 90/256, 90/256), linestyle=":")
fig.fontsize(25)
fig
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ### Strong direct correlation

# %%
x = var('x')
X = np.linspace(0, 50)
Y = (X)  +  2 * np.random.randn(50)
data = np.hstack((X.reshape(50, 1),Y.reshape(50, 1)))
fig = points(data, color='blue', pointsize=50, figsize=(6, 6), gridlines=True, axes_labels=['$x$', '$y$'])
fig += plot(x, (x, 0, 50), ymin=0, ymax=50, gridlines=True, axes_labels=['$x$', '$y$'], figsize=(6, 6), thickness=2.6, rgbcolor=(90/256, 90/256, 90/256), linestyle=":")
fig.fontsize(25)
fig
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ### Perfect direct correlation

# %%
x = var('x')
X = np.linspace(0, 50)
Y = (X)  +  0 * np.random.randn(50)
data = np.hstack((X.reshape(50, 1),Y.reshape(50, 1)))
fig = points(data, color='blue', pointsize=50, figsize=(6, 6), gridlines=True, axes_labels=['$x$', '$y$'])
fig += plot(x, (x, 0, 50), ymin=0, ymax=50, gridlines=True, axes_labels=['$x$', '$y$'], figsize=(6, 6), thickness=2.6, rgbcolor=(90/256, 90/256, 90/256), linestyle=":")
fig.fontsize(25)
fig
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ### Moderate inverse correlation

# %%
x = var('x')
X = np.linspace(0, 50)
Y = (-X) + 50 + 10 * np.random.randn(50)
data = np.hstack((X.reshape(50, 1),Y.reshape(50, 1)))
fig = points(data, color='blue', pointsize=50, figsize=(6, 6), gridlines=True, axes_labels=['$x$', '$y$'])
fig += plot(-x + 50, (x, 0, 50), ymin=0, ymax=50, gridlines=True, axes_labels=['$x$', '$y$'], figsize=(6, 6), thickness=2.6, rgbcolor=(90/256, 90/256, 90/256), linestyle=":")
fig.fontsize(25)
fig
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ### Strong inverse correlation

# %%
x = var('x')
X = np.linspace(0, 50)
Y = (-X) + 50 + 2 * np.random.randn(50)
data = np.hstack((X.reshape(50, 1),Y.reshape(50, 1)))
fig = points(data, color='blue', pointsize=50, figsize=(6, 6), gridlines=True, axes_labels=['$x$', '$y$'])
fig += plot(-x + 50, (x, 0, 50), ymin=0, ymax=50, gridlines=True, axes_labels=['$x$', '$y$'], figsize=(6, 6), thickness=2.6, rgbcolor=(90/256, 90/256, 90/256), linestyle=":")
fig.fontsize(25)
fig
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ### Perfect inverse correlation

# %%
x = var('x')
X = np.linspace(0, 50)
Y = (-X) + 50 + 0 * np.random.randn(50)
data = np.hstack((X.reshape(50, 1),Y.reshape(50, 1)))
fig = points(data, color='blue', pointsize=50, figsize=(6, 6), gridlines=True, axes_labels=['$x$', '$y$'])
fig += plot(-x + 50, (x, 0, 50), ymin=0, ymax=50, gridlines=True, axes_labels=['$x$', '$y$'], figsize=(6, 6), thickness=2.6, rgbcolor=(90/256, 90/256, 90/256), linestyle=":")
fig.fontsize(25)
fig
# Out:
# Graphics object consisting of 2 graphics primitives
